# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df1 = pd.read_excel('/content/SI-assignment.xlsx' , index_col='date')

# %%
df1
# Out:
#             sales
# date
# 2022-11-01   14984
# 2022-11-02    9548
# 2022-11-03   17503
# 2022-11-04    9229
# 2022-11-05   12037
# ...            ...
# 2023-09-26   10470
# 2023-09-27   12954
# 2023-09-28    8660
# 2023-09-29   13234
# 2023-09-30   12500
#
# [334 rows x 1 columns]

# %%
df1.dtypes
# Out:
# sales     int64
# dtype: object

# %%
df1.plot()
plt.show()

# %%
df1_mul_decompose = seasonal_decompose(df1, model = 'additive')
df1_mul_decompose.plot()
plt.show()

# %%
df2 = df1["2022-11-01":"2023-02-28"]
df2.plot()
plt.show()

# %%
df3 = df1["2023-03-01":"2023-06-30"]
df3.plot()
plt.show()

# %%
df4 = df1["2023-07-01":"2023-09-30"]
df4.plot()
plt.show()

# %%
sample1 = df1.sample(100)

# %%
sample2 = df1.sample(100)

# %%
sample3 = df1.sample(100)

# %%
df1.describe()
# Out:
#              sales
# count    334.000000
# mean   10747.538922
# std     2996.371765
# min        0.000000
# 25%     8941.000000
# 50%    10498.000000
# 75%    12330.000000
# max    19864.000000

# %%
sample1.mean()
# Out:
# sales     10844.85
# dtype: float64

# %%
sample2.mean()
# Out:
# sales     10874.3
# dtype: float64

# %%
sample3.mean()
# Out:
# sales     10311.92
# dtype: float64

# %%
from statsmodels.stats.weightstats import ztest as ztest

# %%
ztest(sample1,value = 10747.538922)
# Out:
# (array([0.29263823]), array([0.76979869]))

# %%
ztest(sample2,value = 10747.538922)
# Out:
# (array([0.52206894]), array([0.60162233]))

# %%
ztest(sample3,value = 10747.538922)
# Out:
# (array([-1.44272273]), array([0.14909859]))
